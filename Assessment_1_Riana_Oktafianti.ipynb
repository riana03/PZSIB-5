# %% [markdown]
# <a href="https://colab.research.google.com/github/riana03/PZSIB-5/blob/main/Assessment_1_Riana_Oktafianti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ASSESSMENT 1**
#
# **Nama   : Riana Oktafianti**,
# **Prodi  : Fisika**, **Universitas Negeri Surabaya**

# %%
# Import data github ke google colab

# !git clone https://github.com/dataenergy/Exploratory-data-analysis-of-climate-change-and-natural-disasters.git
# Out:
# fatal: destination path 'Exploratory-data-analysis-of-climate-change-and-natural-disasters' already exists and is not an empty directory.

# %%
# Import library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as pl

# %%
# Membaca file csv yang  digunakan

data = '/content/Exploratory-data-analysis-of-climate-change-and-natural-disasters/datasets/number-of-natural-disaster-events.csv'
df = pd.read_csv(data)
df
# Out:
#                     Entity  Code  Year  \
# 0    All natural disasters   NaN  1900
# 1    All natural disasters   NaN  1901
# 2    All natural disasters   NaN  1902
# 3    All natural disasters   NaN  1903
# 4    All natural disasters   NaN  1904
# ..                     ...   ...   ...
# 823               Wildfire   NaN  2014
# 824               Wildfire   NaN  2015
# 825               Wildfire   NaN  2016
# 826               Wildfire   NaN  2017
# 827               Wildfire   NaN  2018
#
#      Number of reported natural disasters (reported disasters)
# 0                                                    5
# 1                                                    2
# 2                                                    9
# 3                                                    8
# 4                                                    2
# ..                                                 ...
# 823                                                  4
# ...

# %%
# Memisahkan variabel numerik dan variabel categorical
categorical_variables = df.iloc[:, 0]
numerical_variables = df.iloc[:, 2]
numerical_variables_1 = df.iloc[:, 3]

# Menampilkan beberapa baris pertama dari masing-masing variabel
print("Variabel Kategorikal:")
print(categorical_variables.head())

print("\nVariabel Numerik:")
print(numerical_variables.head())

print("\nVariabel Numerik:")
print(numerical_variables_1.head())
# Out:
# Variabel Kategorikal:
# 0    All natural disasters
# 1    All natural disasters
# 2    All natural disasters
# 3    All natural disasters
# 4    All natural disasters
# Name: Entity, dtype: object
#
# Variabel Numerik:
# 0    1900
# 1    1901
# 2    1902
# 3    1903
# 4    1904
# Name: Year, dtype: int64
#
# Variabel Numerik:
# 0    5
# 1    2
# 2    9
# 3    8
# 4    2
# Name: Number of reported natural disasters (reported disasters), dtype: int64

# %% [markdown]
# **Barplot Vertikal**

# %%
# Data untuk membuat barplot
data_barplot = categorical_variables # Entity
data_barplot_1 = numerical_variables #Year
data_barplot_2 = numerical_variables_1 # Number of reported natural disasters


# Membuat barplot vertikal
plt.figure(figsize = (10, 6))
plt.bar(data_barplot, data_barplot_2, color='c')
plt.title('Kejadian Bencana Alam Tahun 1900 - 2018 ', size = 16)
plt.xlabel('Jenis Bencana Alam', size = 12)
plt.ylabel('Total kejadian', size = 12)
plt.xticks(rotation = 60)

# Menampilkan plot
plt.show()

# %%
# Membuat barplot vertikal
plt.figure(figsize = (20, 6))
plt.bar(data_barplot_1, data_barplot_2, color='brown')
plt.title('Kejadian Bencana Alam Tahun 1900 - 2018 ', size = 16)
plt.xlabel('Tahun terjadi', size = 12)
plt.ylabel('Total bencana alam', size = 12)
plt.xticks(rotation = 60)

# Menampilkan plot
plt.show()

# %% [markdown]
# **Barplot Horizontal**

# %%
# Membuat barplot horizontal
plt.figure(figsize=(10, 6))
plt.barh(data_barplot, data_barplot_2, color='m')
plt.title('Kejadian Bencana Alam Tahun 1900 - 2018 ', size = 16)
plt.ylabel('Jenis Bencana Alam', size = 12)
plt.xlabel('Total kejadian', size = 12)

# Menampilkan plot
plt.show()

# %%
# Membuat barplot horizontal
plt.figure(figsize=(10, 12))
plt.barh(data_barplot_1, data_barplot_2, color = 'red')
plt.title('Kejadian Bencana Alam Tahun 1900 - 2018 ', size = 16)
plt.xlabel('Jumlah bencana alam', size = 12)
plt.ylabel('Tahun terjadi', size = 12)

# Menampilkan plot
plt.show()

# %% [markdown]
# **Distplot**

# %%
# Data untuk membuat distplot
data_distplot = categorical_variables # Entity
data_barplot_1 = numerical_variables #Year
data_barplot_2 = numerical_variables_1 # Number of reported natural disasters

# %%
# Membuat distplot
plt.figure(figsize = (10, 6))
sns.histplot(data_distplot, kde = True, color = 'c')
plt.title('Distribusi Data Bencana Alam', size = 16)
plt.xlabel('Nilai Numerik', size = 12)
plt.ylabel('Frekuensi', size = 12)
plt.xticks(rotation = 60)

# Menampilkan plot
plt.show()

# %%
# Membuat distplot
plt.figure(figsize = (10, 6))
sns.histplot(data_barplot_1, kde = True, color = 'yellow')
plt.title('Distribusi Data Numerik', size = 16)
plt.xlabel('Nilai Numerik', size = 12)
plt.ylabel('Frekuensi', size = 12)

# Menampilkan plot
plt.show()

# %%
# Membuat distplot
plt.figure(figsize = (15, 10))
sns.histplot(data_barplot_2, kde = True, color = 'pink')
plt.title('Distribusi Data Numerik', size = 16)
plt.xlabel('Nilai Numerik', size = 12)
plt.ylabel('Frekuensi', size = 12)

# Menampilkan plot
plt.show()

# %% [markdown]
# **Checkpoint 2**

# %%
# Data untuk membuat pie chart
categorical_variables = df.iloc[:, 0]
numerical_variables = df.iloc[:, 2]
numerical_variables_1 = df.iloc[:, 3]

# Menghitung frekuensi data yang digunakan
category_counts = categorical_variables.value_counts()

# Membuat pie chart
plt.figure(figsize=(6, 6))
plt.pie(category_counts, labels=category_counts.index, autopct = '%1.1f%%', startangle = 140)
plt.title('Kejadian Bencana Alam Tahun 1900 - 2018')
plt.axis('equal')
plt.show()

# Pie chart dibawah ini menunjukkan banyaknya categorical_variables yang terdapat pada data csv diatas dengan paling banyak adalah All Natural Disasters

# %% [markdown]
# # Syntax lain yang dapat digunakan (Bar Plot dan Scatter Plot)

# %% [markdown]
# Preparation

# %%
# Import library

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data Collection

# %%
# Import data github ke google colab

# !git clone https://github.com/dataenergy/Exploratory-data-analysis-of-climate-change-and-natural-disasters.git
# Out:
# fatal: destination path 'Exploratory-data-analysis-of-climate-change-and-natural-disasters' already exists and is not an empty directory.

# %%
# Membaca file csv yang  digunakan

data = '/content/Exploratory-data-analysis-of-climate-change-and-natural-disasters/datasets/number-of-natural-disaster-events.csv'
df = pd.read_csv(data)
df
# Out:
#                     Entity  Code  Year  \
# 0    All natural disasters   NaN  1900
# 1    All natural disasters   NaN  1901
# 2    All natural disasters   NaN  1902
# 3    All natural disasters   NaN  1903
# 4    All natural disasters   NaN  1904
# ..                     ...   ...   ...
# 823               Wildfire   NaN  2014
# 824               Wildfire   NaN  2015
# 825               Wildfire   NaN  2016
# 826               Wildfire   NaN  2017
# 827               Wildfire   NaN  2018
#
#      Number of reported natural disasters (reported disasters)
# 0                                                    5
# 1                                                    2
# 2                                                    9
# 3                                                    8
# 4                                                    2
# ..                                                 ...
# 823                                                  4
# ...

# %% [markdown]
# Data Cleansing

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Number of reported natural disasters (reported disasters)'],
#       dtype='object')

# %%
data_nan = df.isnull().sum()

for col in list(data_nan.keys()):
    perc = np.round(data_nan[col] * 100 / len(df), 2)
    print(col + ': ' + str(perc) + '%')
# Out:
# Entity: 0.0%
# Code: 100.0%
# Year: 0.0%
# Number of reported natural disasters (reported disasters): 0.0%

# %%
df.fillna(method ='ffill', inplace = True)
df.isnull().sum()
# Out:
# Jenis Bencana      0
# code             828
# Tahun              0
# Number             0
# dtype: int64

# %%
df.describe()
# Out:
#        Code         Year  \
# count   0.0   828.000000
# mean    NaN  1969.506039
# std     NaN    32.540756
# min     NaN  1900.000000
# 25%     NaN  1946.000000
# 50%     NaN  1975.000000
# 75%     NaN  1997.000000
# max     NaN  2018.000000
#
#        Number of reported natural disasters (reported disasters)
# count                                         828.000000
# mean                                           31.913043
# std                                            67.393086
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             7.000000
# 75%                                            23.000000
# max                                           432.000000

# %%
df.head()
# Out:
#                   Entity  Code  Year  \
# 0  All natural disasters   NaN  1900
# 1  All natural disasters   NaN  1901
# 2  All natural disasters   NaN  1902
# 3  All natural disasters   NaN  1903
# 4  All natural disasters   NaN  1904
#
#    Number of reported natural disasters (reported disasters)
# 0                                                  5
# 1                                                  2
# 2                                                  9
# 3                                                  8
# 4                                                  2

# %%
df = df.rename(columns = {
    'Entity' : 'Jenis Bencana',
    'Code' : 'code',
    'Year' : 'Tahun',
    'Number of reported natural disasters (reported disasters)' : 'Number'
})
df.head()
# Out:
#            Jenis Bencana  code  Tahun  Number
# 0  All natural disasters   NaN   1900       5
# 1  All natural disasters   NaN   1901       2
# 2  All natural disasters   NaN   1902       9
# 3  All natural disasters   NaN   1903       8
# 4  All natural disasters   NaN   1904       2

# %%
df_drought = df[df['Jenis Bencana']=='Drought']
df_drought.head()
# Out:
#     Jenis Bencana  code  Tahun  Number
# 119       Drought   NaN   1900       2
# 120       Drought   NaN   1903       1
# 121       Drought   NaN   1906       1
# 122       Drought   NaN   1910       9
# 123       Drought   NaN   1919       1

# %% [markdown]
# Data Visualization

# %%
plt.bar(df_all['Tahun'][:7], df_all['Number'][:7], color='blue', alpha=1)
plt.title('Kejadian Bencana Alam Tahun 1900 - 1906', size = 16)
plt.xlabel('Tahun', size = 12)
plt.ylabel('Total kejadian', size = 12)
# Out:
# Text(0, 0.5, 'Total kejadian')

# %%
plt.bar(df_all['Tahun'][-7:], df_all['Number'][-7:], color=['red','gray'], alpha=1)
plt.title('Kejadian Bencana Alam Tahun 2012 - 2018', size = 16)
plt.xlabel('Tahun', size = 12)
plt.ylabel('Total kejadian', size = 12)
# Out:
# Text(0, 0.5, 'Total kejadian')

# %%
plt.bar(df['Jenis Bencana'], df['Number'], color='c')
plt.title('Kejadian Bencana Alam Tahun 1900 - 2018 ', size = 16)
plt.ylabel('Total kejadian', size = 12)
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# Scatter Plot

# %%
# Membuat scatter plot dengan grid
plt.scatter(df_all['Tahun'][-7:], df_all['Number'][-7:], color='red', label='Data', s=50)
plt.title('Kejadian Bencana Alam Tahun 2012 - 2018', size=16)
plt.xlabel('Tahun', size=12)
plt.ylabel('Total kejadian', size=12)
plt.grid(True)      # Menambahkan grid
plt.show()

# %%
# Membuat scatter plot tanpa grid
plt.scatter(df_all['Tahun'][:7], df_all['Number'][:7], color='blue', alpha=1)
plt.title('Kejadian Bencana Alam Tahun 1900 - 1906', size=16)
plt.xlabel('Tahun', size=12)
plt.ylabel('Total kejadian', size=12)
plt.show()

# %%
# Membuat scatter plot
plt.scatter(df['Jenis Bencana'], df['Number'], color='c')
plt.title('Kejadian Bencana Alam Tahun 1900 - 2018', size=16)
plt.ylabel('Total kejadian', size=12)
plt.xticks(rotation=60)
plt.show()

# %%
# Membuat scatter plot
plt.scatter(df_all['Tahun'], df_all['Number'], color='red', label='Data', s=50)
plt.title('Kejadian Bencana Alam Tahun 2012 - 2018', size=16)
plt.xlabel('Tahun', size=12)
plt.ylabel('Total kejadian', size=12)
plt.show()
